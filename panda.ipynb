# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # PANDAS SERIES SEQUENCE

# %%
s = pd.Series()
print ("pandas series" , s)
data = np.array(["a","n","s","h"])
s = pd.Series(data)
print("pandas Series\n",s)
# Out:
# pandas series Series([], dtype: object)
# pandas Series
#  0    a
# 1    n
# 2    s
# 3    h
# dtype: object

# %% [markdown]
# # Data Frame

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ["ansh","amit","anuj","anil","anek"]
df = pd.DataFrame(lst)

print(df)
# Out:
#       0
# 0  ansh
# 1  amit
# 2  anuj
# 3  anil
# 4  anek

# %% [markdown]
# # creating a dataframe from list of dictionary

# %%
dict = {"name":
 ["aparna",'anuj','ansh'],
'degree':['mba','bca','btech'],
'score':[20,50,40]}
df =  pd.DataFrame(dict)
print(df)
# Out:
#      name degree  score
# 0  aparna    mba     20
# 1    anuj    bca     50
# 2    ansh  btech     40

# %% [markdown]
# # PANDAS DATAFRAME INDEX

# %%
dict = {"name":
 ["aparna",'anuj','ansh'],
'degree':['mba','bca','btech'],
'score':[20,50,40]}
df =  pd.DataFrame(dict)

print(df)
print(df.index)
# Out:
#      name degree  score
# 0  aparna    mba     20
# 1    anuj    bca     50
# 2    ansh  btech     40
# RangeIndex(start=0, stop=3, step=1)

# %%
df_with_index = df.set_index('degree')
print(df_with_index)
# Out:
#           name  score
# degree
# mba     aparna     20
# bca       anuj     50
# btech     ansh     40

# %%
# reset the index back to the default integer index
df_reset = df.reset_index()
print(df_reset)
# Out:
#    index    name degree  score
# 0      0  aparna    mba     20
# 1      1    anuj    bca     50
# 2      2    ansh  btech     40

# %%
dict = {"name":
 ["aparna",'anuj','ansh'],
'degree':['mba','bca','btech'],
'score':[20,50,40]}
df =  pd.DataFrame(dict)
print(df)
# Out:
#      name degree  score
# 0  aparna    mba     20
# 1    anuj    bca     50
# 2    ansh  btech     40

# %%
# access of column
age = df['degree']
print(age)
# Out:
# 0      mba
# 1      bca
# 2    btech
# Name: degree, dtype: object

# %%
# access of row
pehla = df.iloc[1]
print(pehla)
# Out:
# name      anuj
# degree     bca
# score       50
# Name: 1, dtype: object

# %%
# access multiple row column
access_row_column = df.loc[0:2,['degree','score']]
print(access_row_column)
# Out:
#   degree  score
# 0    mba     20
# 1    bca     50
# 2  btech     40

# %%
data = {'name':['ansh','alice','bob','eve','charlie'],
        'age':[25,30,22,35,28],'gender':['male','female','male','female','male'],'salary':[50000,55000,40000,70000,48000]}
df = pd.DataFrame(data)
print(df)
print(df.index)
# Out:
#       name  age  gender  salary
# 0     ansh   25    male   50000
# 1    alice   30  female   55000
# 2      bob   22    male   40000
# 3      eve   35  female   70000
# 4  charlie   28    male   48000
# RangeIndex(start=0, stop=5, step=1)

# %%
# filtered data
filterdata = df[df['age']>=25]
print(filterdata)
# Out:
#       name  age  gender  salary
# 0     ansh   25    male   50000
# 1    alice   30  female   55000
# 3      eve   35  female   70000
# 4  charlie   28    male   48000

# %%
#  to access specific data
specificdata = df.at[2,'name']
print(specificdata)
# Out:
# bob

# %% [markdown]
# #We'll start "The Group of Seven". Which is a political formed by Canada , France , Germany , italy,Japan the United Kingdom and the United states. We'll start by analyzing population , and for that , we;ll use a pandas.Series object

# %%
# In millionss
g7_pop = pd.Series([35.467,63.951,80.940,60.665,127.061,64.511,318.523])
print(g7_pop)
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
g7_pop.name = ("G7 Population in Millions")
print(g7_pop)
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.dtype
# Out:
# dtype('float64')

# %%
g7_pop.values
# Out:
# array([ 35.467,  63.951,  80.94 ,  60.665, 127.061,  64.511, 318.523])

# %%
type(g7_pop.values)
# Out:
# numpy.ndarray

# %%
g7_pop[3]
# Out:
# np.float64(60.665)

# %%
g7_pop.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
g7_pop.index = ['Canada','France','Germany','Italy','Japan','United Kingdom','United states',]

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United states     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
pd.Series({
    'Canada': 35.467,
    'France': 63.951,
    'Germany': 80.94,
    'Italy': 60.665,
    'Japan': 127.061,
    'United Kingdom': 64.511,
    'United States': 318.523
}, name='G7 Population in millions')
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
pd.Series(
    [35.467, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523],
    index=['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
       'United States'],
    name='G7 Population in millions')
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64

# %%
pd.Series(g7_pop, index=['india','Germany','France'])
# Out:
# india         NaN
# Germany    80.940
# France     63.951
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop['Japan']
# Out:
# np.float64(127.061)

# %%
g7_pop.iloc[0]
# Out:
# np.float64(35.467)

# %%
g7_pop[['Japan','Italy']]
# Out:
# Japan    127.061
# Italy     60.665
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.iloc[[0,1]]
# Out:
# Canada    35.467
# France    63.951
# Name: G7 Population in Millions, dtype: float64

# %%
# we can also use slicing in pandas serires.
# Important Points : In Pandas , the Upper Limit is also included
g7_pop['Germany':'United States']
# Out:
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# Name: G7 Population in Millions, dtype: float64

# %% [markdown]
# # Conditional selection (boolean arrays)
# * The same boolean array techniques we saw applied to numpy arrays can be used for Pandas Series

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United states     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop <89
# Out:
# Canada             True
# France             True
# Germany            True
# Italy              True
# Japan             False
# United Kingdom     True
# United states     False
# Name: G7 Population in Millions, dtype: bool

# %%
g7_pop[g7_pop < 89]
# Out:
# Canada            35.467
# France            63.951
# Germany           80.940
# Italy             60.665
# United Kingdom    64.511
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# np.float64(107.30257142857144)

# %%
g7_pop[g7_pop > g7_pop.mean()]
# Out:
# Japan            127.061
# United states    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.std()
# Out:
# 97.24996987121581

# %%
g7_pop[(g7_pop > g7_pop.mean() - g7_pop.std() / 2 ) | (g7_pop > g7_pop.mean() + g7_pop.std() / 2)]
# Out:
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United states     318.523
# Name: G7 Population in Millions, dtype: float64

# %% [markdown]
# # operation and method
# ## series also support vectorized operation and aggeration functions as numpy

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United states     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop * 1000000
# Out:
# Canada             35467000.0
# France             63951000.0
# Germany            80940000.0
# Italy              60665000.0
# Japan             127061000.0
# United Kingdom     64511000.0
# United states     318523000.0
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# np.float64(107.30257142857144)

# %%
np.log(g7_pop)
# Out:
# Canada            3.568603
# France            4.158117
# Germany           4.393708
# Italy             4.105367
# Japan             4.844667
# United Kingdom    4.166836
# United states     5.763695
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop['France' : 'Italy'].mean()
# Out:
# np.float64(68.51866666666666)

# %%
g7_pop > 80
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United states      True
# Name: G7 Population in Millions, dtype: bool

# %%
g7_pop[(g7_pop > 80 )| (g7_pop < 40)]
# Out:
# Canada            35.467
# Germany           80.940
# Japan            127.061
# United states    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop[(g7_pop > 80 ) & (g7_pop < 200)]
# Out:
# Germany     80.940
# Japan      127.061
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop['Canada'] = 40.5

# %%
g7_pop
# Out:
# Canada             40.500
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United states     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.iloc[-2] = 500

# %%
g7_pop
# Out:
# Canada             40.500
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom    500.000
# United states     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop[g7_pop < 70]
# Out:
# Canada    40.500
# France    63.951
# Italy     60.665
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop[g7_pop<70]= 99.99

# %%
g7_pop
# Out:
# Canada             99.990
# France             99.990
# Germany            80.940
# Italy              99.990
# Japan             127.061
# United Kingdom    500.000
# United states     318.523
# Name: G7 Population in Millions, dtype: float64
